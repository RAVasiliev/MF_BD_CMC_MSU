# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Series

# %%
# pd.Series - набор значений с индексами:
s = pd.Series([1, 2, 3, 4])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
# можем доставать значения по индексу:
s[1]
# Out:
# 194

# %%
# а можем и сразу несколько:

s[[1, 3]]
# Out:
# 1    2
# 3    4
# dtype: int64

# %%
# индексами могут быть не только числа:
s = pd.Series([1, 2, 3, 4], 
               index = ['one', 'two', 'three', 'four'])
s
# Out:
# one      1
# two      2
# three    3
# four     4
# dtype: int64

# %%
# хоть индексы и строки, но мы можем обращаться к элементам по номеру:
s[[1, 3]]
# Out:
# two     2
# four    4
# dtype: int64

# %%
s['three']
# Out:
# 3

# %%
# все индексы:
s.index
# Out:
# Index(['one', 'two', 'three', 'four'], dtype='object')

# %%
# индексы можно поменять:
s.index = ['eins', 'zwei', 'drei', 'vier']

# %%
s
# Out:
# eins    1
# zwei    2
# drei    3
# vier    4
# dtype: int64

# %%
# все значения:
s.values
# Out:
# array([1, 2, 3, 4])

# %%
# можно делать маски:
s > 2
# Out:
# eins    False
# zwei    False
# drei     True
# vier     True
# dtype: bool

# %%
# и затем с помощью масок выбирать значения:
s[s > 2]
# Out:
# drei    3
# vier    4
# dtype: int64

# %%
s1 = pd.Series([1, 2, 4, 5, 6, 99])
s2 = pd.Series([10, 20, 30, 40])

# %%
s1 - s2
# Out:
# 0    -9.0
# 1   -18.0
# 2   -26.0
# 3   -35.0
# 4     NaN
# 5     NaN
# dtype: float64

# %%
s1 = pd.Series([1, 2, 4, 5, 6, 99])
s2 = pd.Series([10, 20, 30, 40, 100, 200])

# %%
s1 + s2
# Out:
# 0     11
# 1     22
# 2     34
# 3     45
# 4    106
# 5    299
# dtype: int64

# %%
s1 * s2
# Out:
# 0       10
# 1       40
# 2      120
# 3      200
# 4      600
# 5    19800
# dtype: int64

# %%
s2 % s1
# Out:
# 0    0
# 1    0
# 2    2
# 3    0
# 4    4
# 5    2
# dtype: int64

# %%
s1
# Out:
# 0     1
# 1     2
# 2     4
# 3     5
# 4     6
# 5    99
# dtype: int64

# %%
# с помощью функции apply можно применить функцию ко всем элементам серии:
s1.apply(lambda x: x ** 3)
# Out:
# 0         1
# 1         8
# 2        64
# 3       125
# 4       216
# 5    970299
# dtype: int64

# %%
# можно передавать функции из numpy:
s1.apply(np.sqrt)
# Out:
# 0    1.000000
# 1    1.414214
# 2    2.000000
# 3    2.236068
# 4    2.449490
# 5    9.949874
# dtype: float64

# %%
def f(x):
  if x > 10:
    return -1
  else:
    return x

# %%
# можно использовать и свою функцию:
s1.apply(lambda x: f(x))
# Out:
# 0    1
# 1    2
# 2    4
# 3    5
# 4    6
# 5   -1
# dtype: int64

# %%
s1.sum()
# Out:
# 117

# %%
s1.mean()
# Out:
# 19.5

# %%
s1
# Out:
# 0     1
# 1     2
# 2     4
# 3     5
# 4     6
# 5    99
# dtype: int64

# %%
s1.cumsum()
# Out:
# 0      1
# 1      3
# 2      7
# 3     12
# 4     18
# 5    117
# dtype: int64

# %%
#Есть очень много чего еще

# %% [markdown]
# # DataFrame

# %%
# DataFrame = объединение нескольких Series

s1 = pd.Series([1, 2, 4, 8, 16])
s2 = pd.Series([1, 3, 9, 27, 81])

ex_df = pd.DataFrame({'Pow of 2': s1, 'Pow of 3': s2})

# %%
ex_df
# Out:
#    Pow of 2  Pow of 3
# 0         1         1
# 1         2         3
# 2         4         9
# 3         8        27
# 4        16        81

# %%
rand_df = pd.DataFrame(np.random.rand(50, 5))
rand_df.head(2)
# Out:
#           0         1         2         3         4
# 0  0.279471  0.830432  0.209298  0.454019  0.739510
# 1  0.818282  0.956071  0.849123  0.585885  0.372828

# %%
# Можем вытащить конкретные столбцы как Series
ex_df['Pow of 2']
# Out:
# 0     1
# 1     2
# 2     4
# 3     8
# 4    16
# Name: Pow of 2, dtype: int64

# %%
# Или так:
new_df = pd.DataFrame({'one': s1, 'two': s2})
new_df.one
# Out:
# 0     1
# 1     2
# 2     4
# 3     8
# 4    16
# Name: one, dtype: int64

# %%
# Можем добавить столбец:
ex_df['Pow of 5'] = pd.Series([5 ** i for i in range(0, 5)])

# %%
ex_df
# Out:
#    Pow of 2  Pow of 3  Pow of 5
# 0         1         1         1
# 1         2         3         5
# 2         4         9        25
# 3         8        27       125
# 4        16        81       625

# %%
#Подвыборка столбцов:
ex_df[['Pow of 2', 'Pow of 5']]
# Out:
#    Pow of 2  Pow of 5
# 0         1         1
# 1         2         5
# 2         4        25
# 3         8       125
# 4        16       625

# %%
# Названия колонок:
ex_df.columns
# Out:
# Index(['Pow of 2', 'Pow of 3', 'Pow of 5'], dtype='object')

# %%
#Названия колонок можно менять
ex_df.columns = ['one', 'two', 'five']
ex_df
# Out:
#    one  two  five
# 0    1    1     1
# 1    2    3     5
# 2    4    9    25
# 3    8   27   125
# 4   16   81   625

# %%
#Можно взять значения
type(ex_df.values)
# Out:
# numpy.ndarray

# %%
#Можно брать срезы
ex_df[3:]
# Out:
#    one  two  five
# 3    8   27   125
# 4   16   81   625

# %%
ex_df.index = ['null', 'eins', 'zwei', 'drei', 'vier']
ex_df
# Out:
#       one  two  five
# null    1    1     1
# eins    2    3     5
# zwei    4    9    25
# drei    8   27   125
# vier   16   81   625

# %%
#Вытаскиваем строку в виде pd.Series ПО НОМЕРУ СТРОКИ
ex_df.iloc[2]
# Out:
# one      4
# two      9
# five    25
# Name: zwei, dtype: int64

# %%
#Вытаскиваем строку в виде pd.Series ПО КОНКРЕТНОМУ ИНДЕКСУ
ex_df.loc['eins']
# Out:
# one     2
# two     3
# five    5
# Name: eins, dtype: int64

# %% [markdown]
# # Работа со внешним DataFrame

# %%
# Загружать можно из csv, excel, SQL и т.д., но чаще всего - csv
df = pd.read_csv('goog.csv')

# %%
#Первые 3 записи
df.head(3)
# Out:
#          Date        Open        High         Low       Close   Volume
# 0  12/19/2016  790.219971  797.659973  786.270020  794.200012  1225900
# 1  12/20/2016  796.760010  798.650024  793.270020  796.419983   925100
# 2  12/21/2016  795.840027  796.676025  787.099976  794.559998  1208700

# %%
# Последние 3 записи
df.tail(3)
# Out:
#          Date        Open        High         Low       Close   Volume
# 58  3/15/2017  847.590027  848.630005  840.770020  847.200012  1379600
# 59  3/16/2017  849.030029  850.849976  846.130005  848.780029   970400
# 60  3/17/2017  851.609985  853.400024  847.109985  852.119995  1712300

# %%
df.shape
# Out:
# (61, 6)

# %%
# Можно сразу при чтении определить что будет индексом
df = pd.read_csv('goog.csv', 
                 parse_dates=['Date'], 
                 index_col='Date')
df.head()
# Out:
#                   Open        High         Low       Close   Volume
# Date
# 2016-12-19  790.219971  797.659973  786.270020  794.200012  1225900
# 2016-12-20  796.760010  798.650024  793.270020  796.419983   925100
# 2016-12-21  795.840027  796.676025  787.099976  794.559998  1208700
# 2016-12-22  792.359985  793.320007  788.580017  791.260010   969100
# 2016-12-23  790.900024  792.739990  787.280029  789.909973   623400

# %%
# описание всего датасета
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 61 entries, 2016-12-19 to 2017-03-17
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    61 non-null     float64
#  1   High    61 non-null     float64
#  2   Low     61 non-null     float64
#  3   Close   61 non-null     float64
#  4   Volume  61 non-null     int64
# dtypes: float64(4), int64(1)
# memory usage: 2.9 KB
# None

# %%
# описание данных
df.describe()
# Out:
#              Open        High         Low       Close        Volume
# count   61.000000   61.000000   61.000000   61.000000  6.100000e+01
# mean   814.005573  817.755576  809.734066  814.561804  1.361269e+06
# std     18.784303   18.556004   19.384799   19.265955  4.987376e+05
# min    778.809998  782.780029  770.409973  771.820007  6.234000e+05
# 25%    799.679993  802.700012  793.270020  801.340027  1.057900e+06
# 50%    809.510010  815.250000  804.539978  809.559998  1.247700e+06
# 75%    828.659973  833.250000  825.059998  830.630005  1.494500e+06
# max    851.609985  853.400024  847.109985  852.119995  3.228900e+06

# %%
# можно навешивать маски для выбора нужных значений
df[df['Open'] > 845]
# Out:
#                   Open        High         Low       Close   Volume
# Date
# 2017-03-15  847.590027  848.630005  840.770020  847.200012  1379600
# 2017-03-16  849.030029  850.849976  846.130005  848.780029   970400
# 2017-03-17  851.609985  853.400024  847.109985  852.119995  1712300

# %%
#Можно применять те же функции что и для pd.Series на весь датасет:

df.mean()
# Out:
# Open      8.140056e+02
# High      8.177556e+02
# Low       8.097341e+02
# Close     8.145618e+02
# Volume    1.361269e+06
# dtype: float64

# %%
df.sum()
# Out:
# Open      4.965434e+04
# High      4.988309e+04
# Low       4.939378e+04
# Close     4.968827e+04
# Volume    8.303740e+07
# dtype: float64

# %%
df.cumsum().head(5)
# Out:
#                    Open         High          Low        Close   Volume
# Date
# 2016-12-19   790.219971   797.659973   786.270020   794.200012  1225900
# 2016-12-20  1586.979981  1596.309997  1579.540040  1590.619995  2151000
# 2016-12-21  2382.820008  2392.986022  2366.640016  2385.179993  3359700
# 2016-12-22  3175.179993  3186.306029  3155.220033  3176.440003  4328800
# 2016-12-23  3966.080017  3979.046019  3942.500062  3966.349976  4952200

# %%
# Всего значений
df.size
# Out:
# 305

# %%
# Размеры датасета
df.shape
# Out:
# (61, 5)

# %%
# Простановка ранков по каждому столбцу
df.rank()
# Out:
#             Open  High   Low  Close  Volume
# Date
# 2016-12-19   6.0  10.0   7.0   10.0    29.0
# 2016-12-20  14.0  12.0  16.0   13.0     7.0
# 2016-12-21  13.0   9.0   8.0   11.0    28.0
# 2016-12-22   9.0   6.0  11.0    7.0     9.0
# 2016-12-23   8.0   5.0   9.0    6.0     1.0
# ...          ...   ...   ...    ...     ...
# 2017-03-13  58.0  59.0  59.0   57.0    23.0
# 2017-03-14  57.0  57.0  58.0   58.0     3.0
# 2017-03-15  59.0  58.0  57.0   59.0    40.0
# 2017-03-16  60.0  60.0  60.0   60.0    10.0
# 2017-03-17  61.0  61.0  61.0   61.0    53.0
#
# [61 rows x 5 columns]

# %%
# Если хотим сохранить датасет чтобы потом не испортить
df_rez = df.copy()

# %%
# Можем использовать функции numpy для столбцов
df_rez['Log_Open'] = np.log(df_rez['Open'])
df_rez.head()
# Out:
#                   Open        High         Low       Close   Volume  Log_Open
# Date
# 2016-12-19  790.219971  797.659973  786.270020  794.200012  1225900  6.672311
# 2016-12-20  796.760010  798.650024  793.270020  796.419983   925100  6.680554
# 2016-12-21  795.840027  796.676025  787.099976  794.559998  1208700  6.679398
# 2016-12-22  792.359985  793.320007  788.580017  791.260010   969100  6.675016
# 2016-12-23  790.900024  792.739990  787.280029  789.909973   623400  6.673172

# %%
# Транспонирование
df_rez.T
# Out:
# Date      2016-12-19     2016-12-20  ...     2017-03-16    2017-03-17
# Open    7.902200e+02     796.760010  ...     849.030029  8.516100e+02
# High    7.976600e+02     798.650024  ...     850.849976  8.534000e+02
# Low     7.862700e+02     793.270020  ...     846.130005  8.471100e+02
# Close   7.942000e+02     796.419983  ...     848.780029  8.521200e+02
# Volume  1.225900e+06  925100.000000  ...  970400.000000  1.712300e+06
#
# [5 rows x 61 columns]

# %%
# Удалить из памяти
del df_rez

# %%
# Сортировка по столбцу
df.sort_values(by='Open')
# Out:
#                   Open        High         Low       Close   Volume
# Date
# 2017-01-03  778.809998  789.630005  775.799988  786.140015  1643100
# 2016-12-30  782.750000  782.780029  770.409973  771.820007  1760200
# 2016-12-29  783.330017  785.929993  778.919983  782.789978   742200
# 2017-01-05  786.080017  794.479980  785.020020  794.020020  1315400
# 2017-01-04  788.359985  791.340027  783.159973  786.900024  1065400
# ...                ...         ...         ...         ...      ...
# 2017-03-14  843.640015  847.239990  840.799988  845.619995   779900
# 2017-03-13  844.000000  848.684998  843.250000  845.539978  1149500
# 2017-03-15  847.590027  848.630005  840.770020  847.200012  1379600
# 2017-03-16  849.030029  850.849976  846.130005  848.780029   970400
# 2017-03-17  851.609985  853.400024  847.109985  852.119995  1712300
#
# [61 rows x 5 columns]

# %%
# удаление столбцов
df_4 = df.drop('Low', axis = 1)
df_4.head()
# Out:
#                   Open        High       Close   Volume
# Date
# 2016-12-19  790.219971  797.659973  794.200012  1225900
# 2016-12-20  796.760010  798.650024  796.419983   925100
# 2016-12-21  795.840027  796.676025  794.559998  1208700
# 2016-12-22  792.359985  793.320007  791.260010   969100
# 2016-12-23  790.900024  792.739990  789.909973   623400

# %%
# столбцы можно складывать
df['Delta'] = df['Close'] - df['Open']
df.head()
# Out:
#                   Open        High         Low       Close   Volume     Delta
# Date
# 2016-12-19  790.219971  797.659973  786.270020  794.200012  1225900  3.980041
# 2016-12-20  796.760010  798.650024  793.270020  796.419983   925100 -0.340027
# 2016-12-21  795.840027  796.676025  787.099976  794.559998  1208700 -1.280029
# 2016-12-22  792.359985  793.320007  788.580017  791.260010   969100 -1.099975
# 2016-12-23  790.900024  792.739990  787.280029  789.909973   623400 -0.990051

# %%
(df['Delta'] > 0).astype(int)
# Out:
# Date
# 2016-12-19    1
# 2016-12-20    0
# 2016-12-21    0
# 2016-12-22    0
# 2016-12-23    0
#              ..
# 2017-03-13    1
# 2017-03-14    1
# 2017-03-15    0
# 2017-03-16    0
# 2017-03-17    1
# Name: Delta, Length: 61, dtype: int64

# %%
df['is_delta_pol'] = (df['Delta'] > 0).astype(int)

# %%
df['Ex'] = 5
df['Ex'] = df['Open'] - df['High']
df.head()
# Out:
#                   Open        High  ...  is_delta_pol        Ex
# Date                                ...
# 2016-12-19  790.219971  797.659973  ...             1 -7.440002
# 2016-12-20  796.760010  798.650024  ...             0 -1.890014
# 2016-12-21  795.840027  796.676025  ...             0 -0.835998
# 2016-12-22  792.359985  793.320007  ...             0 -0.960022
# 2016-12-23  790.900024  792.739990  ...             0 -1.839966
#
# [5 rows x 8 columns]

# %%
#Можно группироваться по конкретным значениям:

df.groupby('is_delta_pol').mean()
# Out:
#                     Open        High  ...     Delta        Ex
# is_delta_pol                          ...
# 0             811.311540  813.144078  ... -3.059617 -1.832538
# 1             816.006855  821.181260  ...  3.242289 -5.174405
#
# [2 rows x 7 columns]

# %%
df.groupby('is_delta_pol').max()
# Out:
#                     Open        High         Low  ...   Volume      Delta        Ex
# is_delta_pol                                      ...
# 0             849.030029  850.849976  846.130005  ...  3228900  -0.030029  0.000000
# 1             851.609985  853.400024  847.109985  ...  1901600  12.059998 -0.395019
#
# [2 rows x 7 columns]

# %%
df.groupby('is_delta_pol').min()
# Out:
#                     Open        High         Low  ...  Volume      Delta         Ex
# is_delta_pol                                      ...
# 0             782.750000  782.780029  770.409973  ...  623400 -12.339966  -7.239990
# 1             778.809998  789.630005  775.799988  ...  779900   0.049988 -13.619995
#
# [2 rows x 7 columns]

# %%
df['min_795'] = df['High'] < 795

# %%
df.groupby(['is_delta_pol', 'min_795']).min()
# Out:
#                             Open        High  ...      Delta         Ex
# is_delta_pol min_795                          ...
# 0            False    795.840027  796.676025  ... -12.339966  -7.239990
#              True     782.750000  782.780029  ... -10.929993  -2.980042
# 1            False    790.219971  797.659973  ...   0.049988 -13.619995
#              True     778.809998  789.630005  ...   7.330017 -10.820007
#
# [4 rows x 7 columns]

# %%
df.reset_index()['Date'].min()
# Out:
# Timestamp('2016-12-19 00:00:00')

# %%
#Сохраняем в таблицу
df.to_csv('res_table.csv', sep = ';')

# %% [markdown]
# Еще больше про pandas:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html
